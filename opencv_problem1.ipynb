# %% [markdown]
# ### Ques: convert an image to stripes of black and white

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread('_DSC3521.JPG')

# %%
image=cv2.resize(image,(640,480))

# %%
plt.imshow(image[:,:,::-1])

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
gray=cv2.cvtColor(gray,cv2.COLOR_GRAY2BGR)
plt.imshow(gray)

# %%
strips=[]
width=int(strip*w/4)
output=np.zeros((480,640))
# print(output.shape)
for strip in range(4):
    if strip%2==0:
        strips.append(image[:,strip*width:(strip+1)*width][:,:,::-1])
    else:
        strips.append(gray2color[:,strip*width:(strip+1)*width])
plt.imshow(np.hstack(strips))

# %%
b,g,r = image[0],image[1],image[3]
# print(b,g,r)
g.shape
# Out:
# (640, 3)
